# %% [markdown]
# # WORKSHEET - NORMAL DISTRIBUTIONS
#
# ## 1. For each problem plot the normal curve with shaded area you have to find.  Let z represent a variable following a standard normal distribution.

# %% [markdown]
# ## (a) Find the proportion that is less than z=2.00

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm


x_min = -5.0
x_max = 5.0

#z represents a variable following a standard normal distribution
#here we assign a variable z's value to 2.00. STUDENT PART: Add 2.00 after the "z =" ------------
z = 2.0

mean = 0 
std_dev = 1.0

#calculate the proportion with the normalcdf function
proportion = norm.cdf(z,mean,std_dev) 
#output proportion to the console 
print ( "The proportion that is less than z = "+ str(z) + " is approximatley " + str( round(proportion, 4) ) )

# Plots normal distribution curve
x = np.linspace(x_min, x_max, 200) 
y = norm.pdf(x, mean, std_dev)
plt.plot(x,y, color='purple')
plt.grid()
plt.xlim(x_min,x_max)
plt.ylim(0,.5)


# Shades the portion of the plot under the curve 
start_pt = x_min
end_pt = z

plt.plot([start_pt ,start_pt ],[0.0,norm.pdf(start_pt, mean, std_dev)], color='purple')
plt.plot([end_pt ,end_pt ],[0.0,norm.pdf(end_pt, mean, std_dev)], color='purple')

ptx = np.linspace(start_pt, end_pt, 200)
pty = norm.pdf(ptx,mean,std_dev)

plt.fill_between(ptx, pty, color='purple', alpha='1.0')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()
# Out:
# The proportion that is less than z = 2.0 is approximatley 0.9772

# %% [markdown]
# ## (b) Find the proportion that is between z=-.13 and z=1.75

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm


x_min = -5.0
x_max = 5.0

#z_upper and lower represent variables following a standard normal distribution
#STUDENT PART: assign a variable z_lower's value and z_upper's value. ----------------------
z_lower = -.13 
z_upper = 1.75
#STUDENT PART: assign mean and std_dev -----------------------
mean = 0 
std_dev = 1.0

#calculate the proportion with the Normalcdf function
prop_lower = norm.cdf(z_lower,mean,std_dev) 
prop_upper = norm.cdf(z_upper,mean,std_dev) 
proportion = prop_upper - prop_lower
#output calculated proportion of the range to the console 
print ( "The proportion that is between z = "+ str(z_lower) + " and " + str(z_upper) +" is approximatley "+ str( round(proportion, 4)) )

# Plots normal distribution curve
x = np.linspace(x_min, x_max, 200) 
y = norm.pdf(x, mean, std_dev)
#STUDENT PART: change the color parameter of plot function to 'blue' don't forget the ''
plt.plot(x,y, color='blue')
plt.grid()
plt.xlim(x_min,x_max)
plt.ylim(0,.5)

# Shades the portion of the plot under the curve 
start_pt = z_lower
end_pt = z_upper

plt.plot([start_pt ,start_pt ],[0.0,norm.pdf(start_pt ,mean, std_dev)], color='purple')
plt.plot([end_pt ,end_pt ],[0.0,norm.pdf(end_pt ,mean, std_dev)], color='purple')

ptx = np.linspace(start_pt, end_pt, 200)
pty = norm.pdf(ptx,mean,std_dev) 


plt.fill_between(ptx, pty, color='purple', alpha='1.0')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()
# Out:
# The proportion that is between z = -0.13 and 1.75 is approximatley 0.5117

# %% [markdown]
# ## (c) Find the proportion that is greater than z=1.86

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm

x_min = -5.0
x_max = 5.0

#z represents a variable following a standard normal distribution 
#STUDENT PART: assign z_lower's value and set z_upper to x_max
z_lower = 1.86
z_upper = x_max
 
mean = 0 
std_dev = 1.0

#calculate the proportion with the normalcdf function
prop_lower = norm.cdf(z_lower,mean,std_dev) 
prop_upper = norm.cdf(z_upper,mean,std_dev)
#STUDENT PART: calculate proportion (hint: look at part 1(b)) 
proportion = prop_upper - prop_lower
#output proportion to the console 
print ("The proportion that is greater than z = "+ str(z_lower) + " is approximatley " + str(round(proportion, 4)))

# Plots normal distribution curve
x = np.linspace(x_min, x_max, 200) 
y = norm.pdf(x, mean, std_dev)
plt.plot(x,y, color='purple')
plt.grid()
plt.xlim(x_min,x_max)
plt.ylim(0,.5)


# Shades the portion of the plot under the curve 
start_pt = z_lower
end_pt = z_upper

plt.plot([start_pt ,start_pt ],[0.0,norm.pdf(start_pt, mean, std_dev)], color='purple')
plt.plot([end_pt ,end_pt ],[0.0,norm.pdf(end_pt, mean, std_dev)], color='purple')

ptx = np.linspace(start_pt, end_pt, 200)
pty = norm.pdf(ptx,mean,std_dev)

plt.fill_between(ptx, pty, color='purple', alpha='1.0')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()
# Out:
# The proportion that is greater than z = 1.86 is approximatley 0.0314

# %% [markdown]
# ## (d) Find the z-score for the 64th percentile

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm

x_min = -5.0
x_max = 5.0
 
mean = 0 
std_dev = 1.0

#calculate the z score with Percent Point Function which is the inverse of normalCDF function
#STUDENT PART: write in .64 as the argument to 
z_score = norm.ppf(.64)

print ( "The z-score ≈ "+ str( round(z_score, 4)) )

# Plots normal distribution curve
x = np.linspace(x_min, x_max, 200) 
y = norm.pdf(x, mean, std_dev)
plt.plot(x,y, color='purple')
plt.grid()
plt.xlim(x_min,x_max)
plt.ylim(0,.5)

# Shades the portion of the plot under the curve 
start_pt = x_min
end_pt = z_score

plt.plot([start_pt ,start_pt ],[0.0,norm.pdf(start_pt, mean, std_dev)], color='purple')
plt.plot([end_pt ,end_pt ],[0.0,norm.pdf(end_pt, mean, std_dev)], color='purple')

ptx = np.linspace(start_pt, end_pt, 200)
pty = norm.pdf(ptx,mean,std_dev)
plt.fill_between(ptx, pty, color='purple', alpha='1.0')

plt.rcParams['figure.figsize'] = [10, 5]
plt.show()
# Out:
# The z-score ≈ 0.3585

# %% [markdown]
# ##  (e) Find the z-scores that bound the middle 50% of all data

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm

x_min = -5.0
x_max = 5.0
 
mean = 0 
std_dev = 1.0

#calculate the z score with Percent Point Function which is the inverse of normalCDF function
#STUDENT PART: put .25 in as the parameter of the norm.ppf()
z_score_lower = norm.ppf(.25)
#STUDENT PART: put .75 in as the parameter of the norm.ppf()
z_score_upper = norm.ppf(.75)

print ( "z-scores ≈ "+ str( round(z_score_lower, 4)) + " and ≈ " + str( round(z_score_upper, 4)))

# Plots normal distribution curve
x = np.linspace(x_min, x_max, 200) 
y = norm.pdf(x, mean, std_dev)
plt.plot(x,y, color='purple')
plt.grid()
plt.xlim(x_min,x_max)
plt.ylim(0,.5)

# Shades the portion of the plot under the curve 
start_pt = z_score_lower
end_pt = z_score_upper

plt.plot([start_pt ,start_pt ],[0.0,norm.pdf(start_pt, mean, std_dev)], color='purple')
plt.plot([end_pt ,end_pt ],[0.0,norm.pdf(end_pt, mean, std_dev)], color='purple')

ptx = np.linspace(start_pt, end_pt, 200)
pty = norm.pdf(ptx,mean,std_dev)

plt.fill_between(ptx, pty, color='purple', alpha='1.0')


plt.rcParams['figure.figsize'] = [10, 5]
plt.show()
# Out:
# z-scores ≈ -0.6745 and ≈ 0.6745

# %% [markdown]
# ## (f) Find the z-score for the 24th percentile

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm

x_min = -5.0
x_max = 5.0
#z represents a variable following a standard normal distribution 
#STUDENT PART: assign z_lower's value to x_min and set z_upper value 
z_lower = x_min
z_upper = -1.2
 
mean = 0 
std_dev = 1.0

#calculate the z score with Percent Point Function which is the inverse of normalCDF function
#STUDENT PART: assign percentile to 0.24
z_score = norm.ppf(0.24)


print ( "The z-score ≈ "+ str( round(z_score, 4)) )

# Plots normal distribution curve
x = np.linspace(x_min, x_max, 200) 
y = norm.pdf(x, mean, std_dev)
plt.plot(x,y, color='purple')
plt.grid()
plt.xlim(x_min,x_max)
plt.ylim(0,.5)

# Shades the portion of the plot under the curve 
start_pt = z_lower
end_pt = z_upper

plt.plot([start_pt ,start_pt ],[0.0,norm.pdf(start_pt, mean, std_dev)], color='purple')
plt.plot([end_pt ,end_pt ],[0.0,norm.pdf(end_pt, mean, std_dev)], color='purple')

ptx = np.linspace(start_pt, end_pt, 200)
pty = norm.pdf(ptx,mean,std_dev)

plt.fill_between(ptx, pty, color='purple', alpha='1.0')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()
# Out:
# The z-score ≈ -0.7063

# %% [markdown]
# ## Former ISU basketball player Kelvin Cato is 83 inches tall.  Assuming that heights follow approximately a normal distruibution with mean 70 and standard deviation = 3

# %% [markdown]
# ## (a) what is his corresponding z-score?

# %%
#This part the students should fill out right hand side 
z_score = (83-70)/3

print ("Cato's z-score = %.2f" % z_score)
# Out:
# Cato's z-score = 4.33

# %% [markdown]
# ## (b) what proportion of men are taller than him?

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm

#STUDENT PART: fill in x_min, x_max, z_score, 
x_min = 55
x_max = 85
cato = 83
z_score = 4.33

#STUDENT PART  
mean = 70.0 
std_dev = 3.0

#calculate the proportion here 
prop_lower = norm.cdf(z_score,0,1) 
proportion =  1 - prop_lower

#output probability  to the console 
print ( "The proportion of men taller than Cato is " + str(proportion))


# Plots normal distribution curve
x = np.linspace(x_min, x_max, 200) 
y = norm.pdf(x, mean, std_dev)
plt.plot(x,y, color='purple')
plt.grid()
plt.xlim(x_min,x_max)
plt.ylim(0,.15)


# Shades the portion of the plot under the curve 
start_pt = cato 
end_pt = x_max

plt.plot([start_pt ,start_pt ],[0.0,norm.pdf(start_pt, mean, std_dev)], color='purple')
plt.plot([end_pt ,end_pt ],[0.0,norm.pdf(end_pt, mean, std_dev)], color='purple')

ptx = np.linspace(start_pt, end_pt, 200)
pty = norm.pdf(ptx,mean,std_dev)

plt.fill_between(ptx, pty, color='blue', alpha='1.0')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()
# Out:
# The proportion of men taller than Cato is 7.455467091355139e-06

# %% [markdown]
# ## 3. Since the length of a downhill ski is related to the height of the individuals renting them, it is fair to assume that a normal distribution would describe the length of women’s skis at rental outlets in Colorado.  The mean of the distribution is 150 cm and the standard deviation is 10 cm.
# (a) What is the proportion of women’s ski lengths that are less than 130 cm?

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm

#This part the students should fill out right hand side 
z_score = (130-150)/10

print ("z = %.2f" % z_score)


#STUDENT PART: fill in x_min, x_max, z_score, 
x_min = 120
x_max = 180


#STUDENT PART  
mean = 150.0
std_dev = 10.0

#calculate the proportion here 
proportion = norm.cdf(z_score,0,1) 


#output probability  to the console 
print ( "The proportion of women's ski lengths less than 130 cm is %.3f" % proportion)


# Plots normal distribution curve
x = np.linspace(x_min, x_max, 200) 
y = norm.pdf(x, mean, std_dev)
plt.plot(x,y, color='purple')
plt.grid()
plt.xlim(x_min,x_max)
plt.ylim(0,.045)


# Shades the portion of the plot under the curve 
start_pt = x_min 
end_pt = 130

plt.plot([start_pt ,start_pt ],[0.0,norm.pdf(start_pt, mean, std_dev)], color='purple')
plt.plot([end_pt ,end_pt ],[0.0,norm.pdf(end_pt, mean, std_dev)], color='purple')

ptx = np.linspace(start_pt, end_pt, 200)
pty = norm.pdf(ptx,mean,std_dev)

plt.fill_between(ptx, pty, color='purple', alpha='1.0')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()
# Out:
# z = -2.00
# The proportion of women's ski lengths less than 130 cm is 0.023

# %% [markdown]
# ## (b) What is the proportion of women's ski lengths that are greater than 125 cm?

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm

#This part the students should fill out right hand side 
z_score = (125-150)/10

print ("z = %.2f" % z_score)


#STUDENT PART: fill in x_min, x_max, z_score, 
x_min = 120
x_max = 180


#STUDENT PART  
mean = 150.0
std_dev = 10.0

#calculate the proportion here 
proportion = norm.cdf(z_score,0,1) 
proportion = 1 - proportion


#output probability  to the console 
print ( "The proportion of women's ski lengths that are greater than 125cm is %.3f" % proportion)


# Plots normal distribution curve
x = np.linspace(x_min, x_max, 200) 
y = norm.pdf(x, mean, std_dev)
plt.plot(x,y, color='purple')
plt.grid()
plt.xlim(x_min,x_max)
plt.ylim(0,.045)


# Shades the portion of the plot under the curve STUDENT PART
start_pt = 125
end_pt = x_max

plt.plot([start_pt ,start_pt ],[0.0,norm.pdf(start_pt, mean, std_dev)], color='purple')
plt.plot([end_pt ,end_pt ],[0.0,norm.pdf(end_pt, mean, std_dev)], color='purple')

ptx = np.linspace(start_pt, end_pt, 200)
pty = norm.pdf(ptx,mean,std_dev)

plt.fill_between(ptx, pty, color='purple', alpha='1.0')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()
# Out:
# z = -2.50
# The proportion of women's ski lengths that are greater than 125cm is 0.994

# %% [markdown]
# ## What is the proportion of women's ski lengths that are between 125 and 155?

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm

#This part the students should fill out right hand side 
z_score = (155-150)/10

print ("z = %.2f" % z_score)


#STUDENT PART: fill in x_min, x_max, z_score, 
x_min = 120
x_max = 180


#STUDENT PART  
mean = 150.0
std_dev = 10.0

#calculate the proportion here 
proportion = norm.cdf(z_score,0,1) 
proportion = 1 - proportion


#output probability  to the console 
print ( "The proportion of women's ski lengths that are greater than 125cm is %.3f" % proportion)


# Plots normal distribution curve
x = np.linspace(x_min, x_max, 200) 
y = norm.pdf(x, mean, std_dev)
plt.plot(x,y, color='purple')
plt.grid()
plt.xlim(x_min,x_max)
plt.ylim(0,.045)


# Shades the portion of the plot under the curve STUDENT PART
start_pt = 125
end_pt = 155

plt.plot([start_pt ,start_pt ],[0.0,norm.pdf(start_pt, mean, std_dev)], color='purple')
plt.plot([end_pt ,end_pt ],[0.0,norm.pdf(end_pt, mean, std_dev)], color='purple')

ptx = np.linspace(start_pt, end_pt, 200)
pty = norm.pdf(ptx,mean,std_dev)

plt.fill_between(ptx, pty, color='purple', alpha='1.0')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()
# Out:
# z = 0.50
# The proportion of women's ski lengths that are greater than 125cm is 0.309

# %% [markdown]
# ## (d) Very long skies are expensive and there are not many people who rent them.  What is the longest women's ski a rental shop should carry so that only 2 percent of the costumers will ask to rent a longer ski?

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm



x_min = 120
x_max = 180


mean = 150.0
std_dev = 10.0

#calculate the z-score here STUDENT PART
z_score = norm.ppf(.98) 

#output z-score to the console 
print ( "The z-score is %.2f" % z_score)

#student solves for x_length STUDENT PART
x_length = (z_score * std_dev) + mean 
print ("The longest women's ski the rental shop should carry is %.1f" % x_length)


# Plots normal distribution curve
x = np.linspace(x_min, x_max, 200) 
y = norm.pdf(x, mean, std_dev)
plt.plot(x,y, color='purple')
plt.grid()
plt.xlim(x_min,x_max)
plt.ylim(0,.045)


# Shades the portion of the plot under the curve STUDENT PART
start_pt = int(x_length)
end_pt = x_max

plt.plot([start_pt ,start_pt ],[0.0,norm.pdf(start_pt, mean, std_dev)], color='purple')
plt.plot([end_pt ,end_pt ],[0.0,norm.pdf(end_pt, mean, std_dev)], color='purple')

ptx = np.linspace(start_pt, end_pt, 200)
pty = norm.pdf(ptx,mean,std_dev)

plt.fill_between(ptx, pty, color='purple', alpha='1.0')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()
# Out:
# The z-score is 2.05
# The longest women's ski the rental shop should carry is 170.5

# %% [markdown]
# ## 4. The BMI for males age 20 to 74 follows approximately a normal distribution with mean=27.9 and standard deviation = 7.8 Use the 68-95-99.7 rule to find

# %% [markdown]
# ## (a) the percentage of males with BMI less than 20.1

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm


x_min = 4.5 #27.9 - 7.8 * 3
x_max = 51.3 #27.9 + 7.8 * 3

#STUDENT PART fill in valiues
mean = 27.9
std_dev = 7.8

#calculate the z-score here STUDENT PART
z_score = (20.1 - 27.9)/ 7.8 

#output z-score to the console 
print ( "The z-score is %.2f" % z_score)

#student solves for percentage STUDENT PART fill in based 68-95-99.7 rule 
percentage = (1 - .68) / 2 # = .16
print ("The percentage of males with BMI less than 20.1 is %.2f" % percentage)


# Plots normal distribution curve
x = np.linspace(x_min, x_max, 200) 
y = norm.pdf(x, mean, std_dev)
plt.plot(x,y, color='purple')
#plt.grid()
plt.xlim(x_min,x_max)
plt.ylim(0,.075)


# Shades the portion of the plot under the curve STUDENT PART
start_pt = x_min
end_pt = 20.1

plt.plot([start_pt ,start_pt ],[0.0,norm.pdf(start_pt, mean, std_dev)], color='purple')
plt.plot([end_pt ,end_pt ],[0.0,norm.pdf(end_pt, mean, std_dev)], color='purple')

ptx = np.linspace(start_pt, end_pt, 200)
pty = norm.pdf(ptx,mean,std_dev)

plt.fill_between(ptx, pty, color='purple', alpha='1.0')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()
# Out:
# The z-score is -1.00
# The percentage of males with BMI less than 20.1 is 0.16

# %% [markdown]
# ## (b) the percentage of males with BMI greater than 12.3

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm


x_min = 4.5 #27.9 - 7.8 * 3
x_max = 51.3 #27.9 + 7.8 * 3

#STUDENT PART fill in valiues
mean = 27.9
std_dev = 7.8

#calculate the z-score here STUDENT PART
z_score = (12.3 - 27.9)/ 7.8 

#output z-score to the console 
print ( "The z-score is %.0f" % z_score)

#student solves for x_length STUDENT PART fill in based 68-95-99.7 rule
percentage = 1 -((1 - .95) / 2)  #  =  .975
print ("The percentage of males with BMI greater than 12.3 is %.3f" % percentage)


# Plots normal distribution curve
x = np.linspace(x_min, x_max, 200) 
y = norm.pdf(x, mean, std_dev)
plt.plot(x,y, color='purple')
#plt.grid()
plt.xlim(x_min,x_max)
plt.ylim(0,.075)


# Shades the portion of the plot under the curve STUDENT PART
start_pt = 12.3
end_pt = x_max

plt.plot([start_pt ,start_pt ],[0.0,norm.pdf(start_pt, mean, std_dev)], color='purple')
plt.plot([end_pt ,end_pt ],[0.0,norm.pdf(end_pt, mean, std_dev)], color='purple')

ptx = np.linspace(start_pt, end_pt, 200)
pty = norm.pdf(ptx,mean,std_dev)

plt.fill_between(ptx, pty, color='purple', alpha='1.0')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()
# Out:
# The z-score is -2
# The percentage of males with BMI greater than 12.3 is 0.975

# %% [markdown]
# ## (c) the BMI values that correspond to the middle 99.7% of the distribution.

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm


x_min = 4.5 - .0015 * 7.8 #27.9 - 7.8 * 3
x_max = 51.3 + .0015 * 7.8 #27.9 + 7.8 * 3

#STUDENT PART fill in valiues
mean = 27.9
std_dev = 7.8

x_low = (-3 * 7.8) + 27.9
x_high = (3 * 7.8) + 27.9


#output z-score to the console 
print ( "The BMI values that correspond to the middle 99.7 of the distribution are %.1f and %.1f " % (x_low, x_high))



# Plots normal distribution curve
x = np.linspace(x_min, x_max, 200) 
y = norm.pdf(x, mean, std_dev)
plt.plot(x,y, color='purple')
#plt.grid()
plt.xlim(x_min,x_max)
plt.ylim(0,.075)


# Shades the portion of the plot under the curve STUDENT PART
start_pt = x_low
end_pt = x_high

plt.plot([start_pt ,start_pt ],[0.0,norm.pdf(start_pt, mean, std_dev)], color='purple')
plt.plot([end_pt ,end_pt ],[0.0,norm.pdf(end_pt, mean, std_dev)], color='purple')

ptx = np.linspace(start_pt, end_pt, 200)
pty = norm.pdf(ptx,mean,std_dev)

plt.fill_between(ptx, pty, color='purple', alpha='1.0')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()
# Out:
# The BMI values that correspond to the middle 99.7 of the distribution are 4.5 and 51.3

# %% [markdown]
# ## (d) the value such that 0.15% of males have BMI's greater than the value

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm


x_min = 4.5 - .0015 * 7.8#27.9 - 7.8 * 3 + .0015 * 7.8
x_max = 51.3 + .0015 * 7.8 #27.9 + 7.8 * 3

#STUDENT PART fill in valiues
mean = 27.9
std_dev = 7.8

x_value = (3 * 7.8) + 27.9


#output z-score to the console 
print ( "The value such that 0.15 percent of males have a BMI greater than the value %.1f " % (x_value))



# Plots normal distribution curve
x = np.linspace(x_min, x_max, 200) 
y = norm.pdf(x, mean, std_dev)
plt.plot(x,y, color='purple')
#plt.grid()
plt.xlim(x_min,x_max)
plt.ylim(0,.075)


# Shades the portion of the plot under the curve STUDENT PART
start_pt = .997
end_pt = x_high
plt.plot([start_pt ,start_pt ],[0.0,norm.pdf(start_pt, mean, std_dev)], color='purple')
plt.plot([end_pt ,end_pt ],[0.0,norm.pdf(end_pt, mean, std_dev)], color='purple')

ptx = np.linspace(start_pt, end_pt, 200)
pty = norm.pdf(ptx,mean,std_dev)

plt.fill_between(ptx, pty, color='purple', alpha='1.0')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()
# Out:
# The value such that 0.15 percent of males have a BMI greater than the value 51.3
